# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

import re

# %%
dataset = 'ZymoEVEN'
path = f'/content/drive/MyDrive/FYP/Tools Outputs/kraken2/output fa/{dataset}'

# %%
# columns of kraken output report
columns_=['status','seq_id','taxonomy_id','length','mapping']

# %%
results_df = pd.read_csv(f'{path}/classification_results.txt',delimiter='\t',header=None, names=columns_)

# %%
results_df
# Out:
#         status                                seq_id  taxonomy_id  length  \
# 0            C  4d4262d4-c552-4b8b-a09f-fc9f58c6e283         1279     503
# 1            C  cd4133d1-f92f-44d0-a85c-3ae93f036256         1613     272
# 2            C  fcf98c1d-38ee-4b11-a243-460abb9d6733         1613     390
# 3            U  91694d0d-293e-418e-ab8b-fd2ecb53610b            0     235
# 4            C  a955709e-96d8-450d-8991-d9cce436d288         1279     237
# ...        ...                                   ...          ...     ...
# 1160521      C  0bd69f28-6848-42fd-a51e-393420633d64         1613     407
# 1160522      U  c3f4286d-4549-498e-89e3-14cedaadd915            0     268
# 1160523      C  cc1c5209-c25f-45d9-8919-f38cd29c4d1d         1613     263
# 1160524      C  113b5622-1641-4c52-8615-214f9320613a         1613     510
# 1160525      C  95e17a7a-19aa-4018-8618-ef6c4dca75d8          287   10135
#
#                                                    mapping
# ...

# %%
filepath = f'/content/drive/MyDrive/FYP/Tools Outputs/kraken2/output fa/{dataset}'

# %%
train_df_labels = pd.read_csv(f'{filepath}/v2/labels/train_{dataset}.csv')
train_df_labels
# Out:
#                                       seq_id            name_minimap  \
# 0       d6e1f7a6-5217-4e01-a46b-8fb486b871dd     Salmonella enterica
# 1       32bda558-9c57-4272-86b3-1999278589f6     Bacillus spizizenii
# 2       8027dab8-bc5b-4891-a773-d5bad39bee40   Enterococcus faecalis
# 3       b8713302-bb2f-4128-9fb9-6a81465974b4  Pseudomonas aeruginosa
# 4       ad066609-b477-4f63-bfc1-1a90a14925de        Escherichia coli
# ...                                      ...                     ...
# 169062  13b4b413-d6e6-44a4-a2af-d40054859bf7     Salmonella enterica
# 169063  1298adc7-77a2-4d9e-9d8a-5ed3c1791b52  Pseudomonas aeruginosa
# 169064  fcdcdf65-99a0-45c2-8914-639dff4460b7     Salmonella enterica
# 169065  231e394a-91ab-46f8-b387-dcba61f1be3f     Bacillus spizizenii
# 169066  40872286-5dfd-4a0c-a1b7-f9002da79ead   Enterococcus faecalis
#
#                    name_kraken
# 0          Salmonella enterica
# 1          Bacillus spizizenii
# 2        Enterococcus faecalis
# ...

# %% [markdown]
# # For Misclassified

# %%
misclassified = train_df_labels[train_df_labels['name_kraken'] != train_df_labels['name_minimap']]
misclassified
# Out:
#                      seq_id             name_minimap               name_kraken
# 1              SRR9328980.4         Escherichia coli     Escherichia sp. E4742
# 6             SRR9328980.10       Bacillus pacificus   Bacillus pseudomycoides
# 65            SRR9328980.94  Cereibacter sphaeroides   Paracoccus kondratievae
# 78           SRR9328980.113       Bacillus pacificus           Bacillus cereus
# 90           SRR9328980.129  Cereibacter sphaeroides  Cereibacter azotoformans
# ...                     ...                      ...                       ...
# 1810196  SRR9328980.2231107       Bacillus pacificus         Bacillus mycoides
# 1810203  SRR9328980.2231114       Bacillus pacificus           Bacillus cereus
# 1810250  SRR9328980.2231167         Escherichia coli   Kosakonia radicincitans
# 1810264  SRR9328980.2231184         Escherichia coli   Kosakonia radicincitans
# 1810275  SRR9328980.2231195                     None    Pseudomonas aeruginosa
#
# ...

# %%
results_df=results_df[results_df['seq_id'].isin(misclassified['seq_id'])]

# %%
results_df
# Out:
#         status              seq_id  taxonomy_id  length  \
# 2            C        SRR9328980.4      2044467    8072
# 8            C       SRR9328980.10        64104    6172
# 78           C       SRR9328980.94       135740    9333
# 92           C      SRR9328980.113       526987   13276
# 105          C      SRR9328980.129        43057    6961
# ...        ...                 ...          ...     ...
# 2023659      C  SRR9328980.2231107         1405    6132
# 2023666      C  SRR9328980.2231114       526992    8330
# 2023715      C  SRR9328980.2231167       283686    5262
# 2023731      C  SRR9328980.2231184       283686    5836
# 2023742      C  SRR9328980.2231195          287   10491
#
#                                                    mapping
# 2        0:12 543:1 0:26 543:5 0:14 543:2 0:5 543:3 0:5...
# 8        0:22 2:5 0:28 2:2 0:127 1386:2 0:21 2:1 0:18 2...
# 78       0:967 1224163:1 0:71 1076:2 0:323 1076:3 0:137...
# ...

# %%
mapping_list = []

for _, row in results_df.iterrows():
    seq_id = row['seq_id']
    taxonomic_id = row['taxonomy_id']
    mapping = row['mapping']
    mapping_dict = {}

    # Splitting each entry on ':'
    mappings = mapping.split(' ')

    for i in range(0, len(mappings)):
        left_val, right_val = mappings[i].split(':')
        # Adding the count to the corresponding key in the dictionary
        mapping_dict[int(left_val)] = mapping_dict.get(int(left_val), 0) + int(right_val)

    list_row = [seq_id, taxonomic_id, mapping_dict]

    # Calculate the weight
    total_mapping_sum = sum(mapping_dict.values())
    weight = mapping_dict.get(taxonomic_id, 0) / total_mapping_sum if total_mapping_sum > 0 else 0

    list_row.append(weight)
    mapping_list.append(list_row)

# %%
len(mapping_list)
# Out:
# 78657

# %%
mapping_list[0]
# Out:
# ['SRR9328980.4',
#  2044467,
#  {0: 7084, 543: 908, 91347: 24, 2: 7, 2044467: 5, 1236: 10},
#  0.0006220452848967405]

# %%
with open(f'{path}/MSA List.txt', "w") as file:
    for item in mapping_list:
        file.write(f"{item}\n")

# %% [markdown]
# # For Full Training Data

# %%
results_df=results_df[results_df['seq_id'].isin(train_df_labels['seq_id'])]

# %%
results_df
# Out:
#         status                                seq_id  taxonomy_id  length  \
# 387          C  86fd9e27-f495-4b6e-8124-0c3dbdcd2c9b        96241    5331
# 388          C  62cf08b0-4463-479f-b041-f4cdbaa1c3ed        28901    5034
# 712          C  108c2d07-003c-468a-a896-20ed550cabe3          287    5091
# 713          C  580a4fd7-b45b-4397-b86f-44edd7302ebc         1280    5061
# 714          C  ec8812f3-39cc-430f-952a-0d458027d892         1280    5222
# ...        ...                                   ...          ...     ...
# 1160483      C  283ad856-e124-4bae-bdaa-1eb62d3d6486         1639    5787
# 1160484      C  a6d5187d-cc1b-4fbb-9387-87aad260d47c          562   30950
# 1160492      C  a6741036-5494-4df6-a42c-7174d639d50c          287   18026
# 1160514      C  9a8fa5ea-bb75-44de-9789-4289e804c35f          287   29085
# 1160525      C  95e17a7a-19aa-4018-8618-ef6c4dca75d8          287   10135
#
#                                                    mapping
# ...

# %%
mapping_list = []

for _, row in results_df.iterrows():
    seq_id = row['seq_id']
    taxonomic_id = row['taxonomy_id']
    mapping = row['mapping']
    mapping_dict = {}

    # Splitting each entry on ':'
    mappings = mapping.split(' ')
    if mappings[-1]=='':
      mappings=mappings.pop()

    for i in range(0, len(mappings)):
        left_val, right_val = mappings[i].split(':')
        # Adding the count to the corresponding key in the dictionary
        mapping_dict[left_val] = mapping_dict.get(left_val, 0) + int(right_val)

    list_row = [seq_id, taxonomic_id, mapping_dict]

    # Calculate the weight
    total_mapping_sum = sum(mapping_dict.values())
    weight = mapping_dict.get(str(taxonomic_id), 0) / total_mapping_sum if total_mapping_sum > 0 else 0

    list_row.append(weight)
    mapping_list.append(list_row)

# %%
weights_df = pd.DataFrame(mapping_list, columns=['seq_id', 'taxonomic_id', 'mapping', 'weight'])

# %%
len(mapping_list)
# Out:
# 169067

# %%
mapping_list[0]
# Out:
# ['86fd9e27-f495-4b6e-8124-0c3dbdcd2c9b',
#  96241,
#  {'0': 4995,
#   '1386': 189,
#   '96241': 82,
#   '186817': 5,
#   '653685': 21,
#   '1385': 2,
#   '2685834': 3},
#  0.015480460638097037]

# %%
weights_df
# Out:
#                                       seq_id  taxonomic_id  \
# 0       86fd9e27-f495-4b6e-8124-0c3dbdcd2c9b         96241
# 1       62cf08b0-4463-479f-b041-f4cdbaa1c3ed         28901
# 2       108c2d07-003c-468a-a896-20ed550cabe3           287
# 3       580a4fd7-b45b-4397-b86f-44edd7302ebc          1280
# 4       ec8812f3-39cc-430f-952a-0d458027d892          1280
# ...                                      ...           ...
# 169062  283ad856-e124-4bae-bdaa-1eb62d3d6486          1639
# 169063  a6d5187d-cc1b-4fbb-9387-87aad260d47c           562
# 169064  a6741036-5494-4df6-a42c-7174d639d50c           287
# 169065  9a8fa5ea-bb75-44de-9789-4289e804c35f           287
# 169066  95e17a7a-19aa-4018-8618-ef6c4dca75d8           287
#
#                                                   mapping    weight
# 0       {'0': 4995, '1386': 189, '96241': 82, '186817'...  0.015480
# 1       {'0': 4827, '1': 109, '590': 5, '28901': 23, '...  0.004600
# ...

# %%
# Assuming you have already created the DataFrame 'df' as mentioned before

# Extract the 'weight' column for standardization
weights = weights_df['weight'].values.reshape(-1, 1)

# Initialize the StandardScaler
scaler = MinMaxScaler()

# Fit and transform the weights
weights_df['weight_standardized'] = scaler.fit_transform(weights)

# %%
weights_df
# Out:
#                                       seq_id  taxonomic_id  \
# 0       86fd9e27-f495-4b6e-8124-0c3dbdcd2c9b         96241
# 1       62cf08b0-4463-479f-b041-f4cdbaa1c3ed         28901
# 2       108c2d07-003c-468a-a896-20ed550cabe3           287
# 3       580a4fd7-b45b-4397-b86f-44edd7302ebc          1280
# 4       ec8812f3-39cc-430f-952a-0d458027d892          1280
# ...                                      ...           ...
# 169062  283ad856-e124-4bae-bdaa-1eb62d3d6486          1639
# 169063  a6d5187d-cc1b-4fbb-9387-87aad260d47c           562
# 169064  a6741036-5494-4df6-a42c-7174d639d50c           287
# 169065  9a8fa5ea-bb75-44de-9789-4289e804c35f           287
# 169066  95e17a7a-19aa-4018-8618-ef6c4dca75d8           287
#
#                                                   mapping    weight  \
# 0       {'0': 4995, '1386': 189, '96241': 82, '186817'...  0.015480
# 1       {'0': 4827, '1': 109, '590': 5, '28901': 23, '...  0.004600
# ...

# %%
train_df_labels['weight']=weights_df['weight']
train_df_labels['weight_standardized']=weights_df['weight_standardized']
train_df_labels
# Out:
#                                       seq_id            name_minimap  \
# 0       d6e1f7a6-5217-4e01-a46b-8fb486b871dd     Salmonella enterica
# 1       32bda558-9c57-4272-86b3-1999278589f6     Bacillus spizizenii
# 2       8027dab8-bc5b-4891-a773-d5bad39bee40   Enterococcus faecalis
# 3       b8713302-bb2f-4128-9fb9-6a81465974b4  Pseudomonas aeruginosa
# 4       ad066609-b477-4f63-bfc1-1a90a14925de        Escherichia coli
# ...                                      ...                     ...
# 169062  13b4b413-d6e6-44a4-a2af-d40054859bf7     Salmonella enterica
# 169063  1298adc7-77a2-4d9e-9d8a-5ed3c1791b52  Pseudomonas aeruginosa
# 169064  fcdcdf65-99a0-45c2-8914-639dff4460b7     Salmonella enterica
# 169065  231e394a-91ab-46f8-b387-dcba61f1be3f     Bacillus spizizenii
# 169066  40872286-5dfd-4a0c-a1b7-f9002da79ead   Enterococcus faecalis
#
#                    name_kraken    weight  weight_standardized
# 0          Salmonella enterica  0.015480             0.179804
# ...

# %%
weights_df.to_csv(f'{path}/{dataset}_with_kraken_weights.csv', index=None)

# %%
train_df_labels.to_csv(f'{filepath}/v2/labels/train_{dataset}_with_weights.csv')
