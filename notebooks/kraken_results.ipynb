# %% [markdown]
# ⚠️ If you are mounting your google drive in Colab, run the following cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import re

# %%
# Define path to Kraken2 classification results
result_path = f"output"
result_path
# Out:
# 'output'

# %% [markdown]
# ## Analysis of report

# %%
# columns of kraken output report
columns = ['percentage', 'count', 'coverage', 'taxon', 'taxonomy_id', 'name']

# %%
# read the report file
df = pd.read_table(f'{result_path}/report.txt',header=None,names=columns)

# %%
df.shape
# Out:
# (1421, 6)

# %%
df.head()
# Out:
#    percentage   count  coverage taxon  taxonomy_id                       name
# 0        0.06      99        99     U            0               unclassified
# 1       99.94  179145         8     R            1                       root
# 2       99.94  179136        12    R1       131567         cellular organisms
# 3       95.87  171833        14     D            2                   Bacteria
# 4       57.71  103434         6    D1      1783272        Terrabacteria group

# %% [markdown]
# ## Analysis of classification result

# %%
# columns of kraken output report
columns_=['status','seq_id','taxonomy_id','length','mapping']

# %%
results_df = pd.read_csv(f'{result_path}/output.txt',delimiter='\t',header=None, names=columns_)

# %%
results_df.head()
# Out:
#   status                                seq_id  taxonomy_id  length  \
# 0      C  08628297-d792-4b1b-8d58-40e7232f28d0         1637    5435
# 1      C  86fd9e27-f495-4b6e-8124-0c3dbdcd2c9b        96241    5331
# 2      C  62cf08b0-4463-479f-b041-f4cdbaa1c3ed        28901    5034
# 3      C  108c2d07-003c-468a-a896-20ed550cabe3          287    5091
# 4      C  580a4fd7-b45b-4397-b86f-44edd7302ebc         1280    5061
#
#                                              mapping
# 0  0:138 1637:5 0:30 1637:1 0:34 1637:1 0:8 1637:...
# 1  0:120 1386:5 96241:3 0:61 1386:5 0:5 1386:5 0:...
# 2  0:102 1:1 0:16 590:5 0:30 1:5 0:3 1:2 0:81 289...
# 3  0:1169 287:1 0:695 286:4 0:890 135621:4 0:93 1...
# 4  0:49 1279:5 0:181 1279:1 0:35 1279:3 0:5 1279:...

# %%
results_df.shape
# Out:
# (179244, 5)

# %%
# Merge the two dataframes using taxonomy_id
merged_df = pd.merge(results_df[['seq_id','status','taxonomy_id']],df[['taxonomy_id','taxon','name']],on='taxonomy_id',how='left')

# %%
merged_df.head(20)
# Out:
#                                   seq_id status  taxonomy_id taxon  \
# 0   08628297-d792-4b1b-8d58-40e7232f28d0      C         1637     G
# 1   86fd9e27-f495-4b6e-8124-0c3dbdcd2c9b      C        96241     S
# 2   62cf08b0-4463-479f-b041-f4cdbaa1c3ed      C        28901     S
# 3   108c2d07-003c-468a-a896-20ed550cabe3      C          287     S
# 4   580a4fd7-b45b-4397-b86f-44edd7302ebc      C         1280     S
# 5   ec8812f3-39cc-430f-952a-0d458027d892      C         1280     S
# 6   f74001aa-1fa4-4609-a71e-32c3a56036b9      C         1280     S
# 7   15f27e72-3921-403e-beb5-57b94870a405      C       559292    S1
# 8   5e7c6d52-427b-4a79-b3ab-42d129fabce5      C         1280     S
# 9   2a76382b-53f7-4a30-b3c9-aa03bb8466f0      C        96241     S
# 10  c80a335d-87af-4bdb-9c6c-7f1835330ce4      C         1351     S
# 11  5de27d60-6c89-4a92-a0f4-745428716f06      C        96241     S
# 12  d6b90180-fe80-4a59-bf21-8cc2d87a460a      C          287     S
# 13  06dec09c-f289-4610-a48d-37bf89dd15fd      C         1351     S
# 14  93956392-04fa-461d-8f9d-26c0813574e8      C          562     S
# 15  b2c6b01b-8e26-4942-855d-8d73897a5705      C        96241     S
# 16  798bb688-120c-4522-b4b5-060c81f28918      C         1280     S
# 17  d3a57cf9-b44e-461b-8fd1-f8642c34b8ad      C          287     S
# 18  fde7879d-2de8-4a8d-81b0-bca5999da477      U            0     U
# 19  de53d566-9c0b-4624-bd2e-f1ad3d11003b      C         1351     S
#
#                                                  name
# 0                                            Listeria
# 1                                 Bacillus spizizenii
# 2                                 Salmonella enterica
# 3                              Pseudomonas aeruginosa
# 4                               Staphylococcus aureus
# 5                               Staphylococcus aureus
# 6                               Staphylococcus aureus
# 7                               Saccharomyces cere...
# 8                               Staphylococcus aureus
# 9                                 Bacillus spizizenii
# 10                              Enterococcus faecalis
# 11                                Bacillus spizizenii
# 12                             Pseudomonas aeruginosa
# 13                              Enterococcus faecalis
# 14                                   Escherichia coli
# 15                                Bacillus spizizenii
# 16                              Staphylococcus aureus
# 17                             Pseudomonas aeruginosa
# 18                                       unclassified
# 19                              Enterococcus faecalis

# %%
merged_df.to_csv(f'{result_path}/kraken2.csv',index=False)
