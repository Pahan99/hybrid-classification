# %% [markdown]
# <a href="https://colab.research.google.com/github/Pahan99/hybrid-classification/blob/main/minimap_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
with open('/content/drive/MyDrive/fyp code/combined.paf','r') as f:
    df = pd.read_csv(f,sep='\t',header=None)

# %%
df.head()
# Out:
#                                      0    1   2    3  4   \
# 0  4d4262d4-c552-4b8b-a09f-fc9f58c6e283  503  44  472  +
# 1  a955709e-96d8-450d-8991-d9cce436d288  237  69  230  -
# 2  1c09cf9d-c569-4489-818e-8c0555afc2cb  352  30  335  +
# 3  ec76abdc-7854-40fb-9afa-8b02c3341e46  388  31  371  -
# 4  d532dd45-4bd2-4335-bd62-f418d4864a1b  585  30  568  +
#
#                                       5        6        7        8    9    10  \
# 0       Staphylococcus_aureus_chromosome  2718780  1544329  1544753  360  432
# 1       Staphylococcus_aureus_chromosome  2718780   228241   228400  135  161
# 2            Escherichia_coli_chromosome  4765434  2811326  2811631  261  306
# 3  Enterococcus_faecalis_complete_genome  2845392  1162463  1162805  311  344
# 4  Enterococcus_faecalis_complete_genome  2845392  1739733  1740270  390  540
#
#    11      12       13        14      15           16      17
# 0  60  tp:A:P  cm:i:53  s1:i:356  s2:i:0  dv:f:0.0037  rl:i:0
# ...

# %%
# Check if there are any duplicated reads
df[df.iloc[:,0].duplicated()][0].value_counts()
# Out:
# 31d6bfef-b463-4984-ab34-a5255b22015c    23
# a2894163-8438-4ec0-9f66-825bc547647c    18
# 10c68a79-1574-4526-a7d0-20e207d60a7f    17
# b476e08f-09ed-4751-b536-9e5ec1d19c9b    17
# 94709e85-b529-42e8-826d-db0d35b6e024    16
#                                         ..
# e8b6824f-ed2a-4580-8339-6740136b6def     1
# 72398cec-08b5-4fc5-a070-ffdd460b30fd     1
# 82f84c02-bbd9-4bbc-8747-c23a0a2256ec     1
# 0927f44c-6cd2-4c32-b90a-d5953f7440f3     1
# 95e17a7a-19aa-4018-8618-ef6c4dca75d8     1
# Name: 0, Length: 36085, dtype: int64

# %%
# Filter columns with seq_id and label
result_df = df.iloc[:,[0,5]]
result_df.head()
# Out:
#                                       0                                      5
# 0  4d4262d4-c552-4b8b-a09f-fc9f58c6e283       Staphylococcus_aureus_chromosome
# 1  a955709e-96d8-450d-8991-d9cce436d288       Staphylococcus_aureus_chromosome
# 2  1c09cf9d-c569-4489-818e-8c0555afc2cb            Escherichia_coli_chromosome
# 3  ec76abdc-7854-40fb-9afa-8b02c3341e46  Enterococcus_faecalis_complete_genome
# 4  d532dd45-4bd2-4335-bd62-f418d4864a1b  Enterococcus_faecalis_complete_genome

# %%
result_df.shape
# Out:
# (450093, 2)

# %%
result_df.columns = ['seq_id','name']
result_df.head()
# Out:
#                                  seq_id                                   name
# 0  4d4262d4-c552-4b8b-a09f-fc9f58c6e283       Staphylococcus_aureus_chromosome
# 1  a955709e-96d8-450d-8991-d9cce436d288       Staphylococcus_aureus_chromosome
# 2  1c09cf9d-c569-4489-818e-8c0555afc2cb            Escherichia_coli_chromosome
# 3  ec76abdc-7854-40fb-9afa-8b02c3341e46  Enterococcus_faecalis_complete_genome
# 4  d532dd45-4bd2-4335-bd62-f418d4864a1b  Enterococcus_faecalis_complete_genome

# %%
# Remove duplicated rows
result_df = result_df[~result_df['seq_id'].duplicated()]

# %%
result_df.shape
# Out:
# (368024, 2)

# %%
result_df.to_csv('/content/drive/MyDrive/fyp code/minimap/combined_minimap.csv',index=False)

# %%
np.save('/content/drive/MyDrive/fyp code/minimap/minimap_ids.npy',result_df.seq_id)
