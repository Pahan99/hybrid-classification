# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import re

# %%
# Mention dataset, bin count and version for experiment
# Note: bin_count is only applicable for simulated datasets. For real datasets, it is assign None.
dataset = 'simlord'
bin_count = 10
version = 2

bins = bin_count if dataset == 'simlord' else None

# %%
# Define path to Kraken2 classification results
result_path = f"/content/drive/MyDrive/FYP/FYP/Tools Outputs/kraken2/output fa/{dataset}{'/bin_'+str(bins) if bins != None else '/'}/v{version}"
result_path
# Out:
# '/content/drive/MyDrive/FYP/FYP/Tools Outputs/kraken2/output fa/simlord/bin_10/v2'

# %% [markdown]
# ## Analysis of report

# %%
# columns of kraken output report
columns = ['percentage', 'count', 'coverage', 'taxon', 'taxonomy_id', 'name']

# %%
# read the report file
df = pd.read_table(f'{result_path}/report.txt',header=None,names=columns)

# %%
df.shape
# Out:
# (2303, 6)

# %%
df.head()
# Out:
#    percentage   count  coverage taxon  taxonomy_id                       name
# 0        0.03     158       158     U            0               unclassified
# 1       99.97  499842       197     R            1                       root
# 2       99.93  499644       346    R1       131567         cellular organisms
# 3       80.63  403161       236     D            2                   Bacteria
# 4       50.60  253002       118    D1      1783272        Terrabacteria group

# %% [markdown]
# ## Analysis of classification result

# %%
# columns of kraken output report
columns_=['status','seq_id','taxonomy_id','length','mapping']

# %%
results_df = pd.read_csv(f'{result_path}/output.txt',delimiter='\t',header=None, names=columns_)

# %%
results_df.head()
# Out:
#   status seq_id  taxonomy_id  length  \
# 0      C   seq1         1613    5000
# 1      C   seq2         1279    5000
# 2      C   seq3         1280    5000
# 3      C   seq4         1613    5000
# 4      C   seq5        59201    5000
#
#                                              mapping
# 0  0:78 1613:4 0:3 1613:2 0:13 1613:5 0:9 1613:2 ...
# 1  0:187 1279:5 0:489 1279:1 0:444 1279:2 0:52 12...
# 2  0:121 1279:3 0:24 1279:2 0:178 1279:6 0:12 127...
# 3  0:490 1613:5 0:2 1613:5 0:79 2:5 0:114 1613:5 ...
# 4  0:61 590:3 0:57 590:1 0:233 543:2 0:6 590:2 0:...

# %%
results_df.shape
# Out:
# (500000, 5)

# %%
# Merge the two dataframes using taxonomy_id
merged_df = pd.merge(results_df[['seq_id','status','taxonomy_id']],df[['taxonomy_id','taxon','name']],on='taxonomy_id',how='left')

# %%
merged_df.head(20)
# Out:
#    seq_id status  taxonomy_id taxon  \
# 0    seq1      C         1613     S
# 1    seq2      C         1279     G
# 2    seq3      C         1280     S
# 3    seq4      C         1613     S
# 4    seq5      C        59201    S1
# 5    seq6      C        96241     S
# 6    seq7      C         1280     S
# 7    seq8      C         1637     G
# 8    seq9      C         1351     S
# 9   seq10      C        59201    S1
# 10  seq11      C       559292    S1
# 11  seq12      C        28901     S
# 12  seq13      C       559292    S1
# 13  seq14      C         1351     S
# 14  seq15      C         1351     S
# 15  seq16      C         1351     S
# 16  seq17      C         1351     S
# 17  seq18      C        96241     S
# 18  seq19      C        96241     S
# 19  seq20      C        96241     S
#
#                                                  name
# 0                       Limosilactobacillus fermentum
# 1                                      Staphylococcus
# 2                               Staphylococcus aureus
# 3                       Limosilactobacillus fermentum
# 4                     Salmonella enterica subsp. e...
# 5                                 Bacillus spizizenii
# 6                               Staphylococcus aureus
# 7                                            Listeria
# 8                               Enterococcus faecalis
# 9                     Salmonella enterica subsp. e...
# 10                              Saccharomyces cere...
# 11                                Salmonella enterica
# 12                              Saccharomyces cere...
# 13                              Enterococcus faecalis
# 14                              Enterococcus faecalis
# 15                              Enterococcus faecalis
# 16                              Enterococcus faecalis
# 17                                Bacillus spizizenii
# 18                                Bacillus spizizenii
# 19                                Bacillus spizizenii

# %%
merged_df.to_csv(f'{result_path}/kraken2.csv',index=False)

# %% [markdown]
# # Analysis of Results

# %%
# columns of kraken output report
columns = ['percentage', 'count', 'coverage', 'taxon', 'taxonomy_id', 'name']

# %%
# read the report file
df = pd.read_table(f'{result_path}/report.txt',header=None,names=columns)

# %%
df.head()
# Out:
#    percentage   count  coverage taxon  taxonomy_id                       name
# 0        0.03     158       158     U            0               unclassified
# 1       99.97  499842       197     R            1                       root
# 2       99.93  499644       346    R1       131567         cellular organisms
# 3       80.63  403161       236     D            2                   Bacteria
# 4       50.60  253002       118    D1      1783272        Terrabacteria group

# %%
df.shape
# Out:
# (2303, 6)

# %%
# columns of kraken output report
columns_=['status','seq_id','taxonomy_id','length','mapping']

# %%
results_df = pd.read_csv(f'{result_path}/classification_results.txt',delimiter='\t',header=None, names=columns_)

# %%
results_df.head()
# Out:
#   status                                seq_id  taxonomy_id  length  \
# 0      C  4d4262d4-c552-4b8b-a09f-fc9f58c6e283         1279     503
# 1      C  cd4133d1-f92f-44d0-a85c-3ae93f036256         1613     272
# 2      C  fcf98c1d-38ee-4b11-a243-460abb9d6733         1613     390
# 3      U  91694d0d-293e-418e-ab8b-fd2ecb53610b            0     235
# 4      C  a955709e-96d8-450d-8991-d9cce436d288         1279     237
#
#                                              mapping
# 0  0:55 1279:3 0:223 1279:5 0:20 1279:1 0:32 1279...
# 1  0:69 1613:1 0:25 1613:1 0:5 1613:1 0:37 1613:6...
# 2  0:52 2:1 0:7 2:5 0:103 1613:1 0:5 1613:2 0:66 ...
# 3                                              0:201
# 4            0:99 1279:5 0:20 1279:5 0:2 1279:2 0:70

# %%
# Merge the two dataframes using taxonomy_id
merged_df = pd.merge(results_df[['seq_id','status','taxonomy_id']],df[['taxonomy_id','taxon','name']],on='taxonomy_id',how='left')

# %%
merged_df.head(20)
# Out:
#                                   seq_id status  taxonomy_id taxon  \
# 0   4d4262d4-c552-4b8b-a09f-fc9f58c6e283      C         1279     G
# 1   cd4133d1-f92f-44d0-a85c-3ae93f036256      C         1613     S
# 2   fcf98c1d-38ee-4b11-a243-460abb9d6733      C         1613     S
# 3   91694d0d-293e-418e-ab8b-fd2ecb53610b      U            0     U
# 4   a955709e-96d8-450d-8991-d9cce436d288      C         1279     G
# 5   0dfc8a31-5140-473e-b707-d6dd314f3347      C         1613     S
# 6   e6353177-62b7-4f0f-9464-b80b81851aa3      U            0     U
# 7   9f6f6c5f-80e7-4335-aae2-b7f4666c4e3a      C        33958     F
# 8   1c09cf9d-c569-4489-818e-8c0555afc2cb      C          543     F
# 9   43edd670-7e2a-4ea7-8d2f-6879a5f7d93a      C         1613     S
# 10  ef8b8e61-a9cd-4679-9f46-849d414a03c8      C         1613     S
# 11  5164da88-f86b-48fd-a8b1-aecfcb3dc2e9      C         1613     S
# 12  8f793650-47ce-4146-8127-41ecc4a727f5      C         1613     S
# 13  f3368df9-a982-46ee-850f-6a564ec1efaf      U            0     U
# 14  d9363ab7-3c44-44d8-83ac-571fb6d491bd      C         1613     S
# 15  6944477a-d99e-4abd-a85d-c707add4b68e      C         1613     S
# 16  ec76abdc-7854-40fb-9afa-8b02c3341e46      U            0     U
# 17  d44e9c05-157d-42d7-bcc8-3b680a362776      C         1613     S
# 18  c83fc465-676d-4bea-9f9b-0632746f53cb      C         1613     S
# 19  4f69302d-4980-44fd-9ead-dcee34d914d1      C         1613     S
#
#                                                name
# 0                                    Staphylococcus
# 1                     Limosilactobacillus fermentum
# 2                     Limosilactobacillus fermentum
# 3                                      unclassified
# 4                                    Staphylococcus
# 5                     Limosilactobacillus fermentum
# 6                                      unclassified
# 7                                  Lactobacillaceae
# 8                                Enterobacteriaceae
# 9                     Limosilactobacillus fermentum
# 10                    Limosilactobacillus fermentum
# 11                    Limosilactobacillus fermentum
# 12                    Limosilactobacillus fermentum
# 13                                     unclassified
# 14                    Limosilactobacillus fermentum
# 15                    Limosilactobacillus fermentum
# 16                                     unclassified
# 17                    Limosilactobacillus fermentum
# 18                    Limosilactobacillus fermentum
# 19                    Limosilactobacillus fermentum

# %%
merged_df.to_csv(f'{result_path}/kraken2.csv',index=False)
