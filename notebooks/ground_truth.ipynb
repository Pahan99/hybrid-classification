# %% [markdown]
# ⚠️ If you are mounting your google drive in Colab, run the following cell.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %%
# Provide path to Kraken2 output
kraken_path = f"output"
kraken_path
# Out:
# '/content/drive/MyDrive/fyp code/Tools Outputs/kraken2/output fa/simlord/bin_10/v2'

# %%
label_path = f"label_path"
label_path
# Out:
# '/content/drive/MyDrive/fyp code/Tools Outputs/minimap2/simlord/bin_10/v2'

# %% [markdown]
# 1. Kraken2 output

# %%
kraken_df = pd.read_csv(f'{kraken_path}/kraken_final.csv')
kraken_df.head()
# Out:
#   seq_id status  taxonomy_id taxon                                 name  \
# 0   seq1      C         1613     S        Limosilactobacillus fermentum
# 1   seq2      C         1279     G                       Staphylococcus
# 2   seq3      C         1280     S                Staphylococcus aureus
# 3   seq4      C         1613     S        Limosilactobacillus fermentum
# 4   seq5      C        59201    S1  Salmonella enterica subsp. enterica
#
#                          species                genus
# 0  Limosilactobacillus fermentum  Limosilactobacillus
# 1                        unknown       Staphylococcus
# 2          Staphylococcus aureus       Staphylococcus
# 3  Limosilactobacillus fermentum  Limosilactobacillus
# 4            Salmonella enterica           Salmonella

# %%
kraken_df.rename(columns={'species':'name_kraken'},inplace=True)

# %%
kraken_df.shape
# Out:
# (500000, 7)

# %% [markdown]
# 2. Ground Truth

# %%
truth_df = pd.read_csv(f'{label_path}/ground_truth.csv')
truth_df.head()
# Out:
#   seq_id                                     name
# 0   seq1  Lactobacillus_fermentum_complete_genome
# 1   seq2         Staphylococcus_aureus_chromosome
# 2   seq3         Staphylococcus_aureus_chromosome
# 3   seq4  Lactobacillus_fermentum_complete_genome
# 4   seq5      Salmonella_enterica_complete_genome

# %%
truth_df.shape
# Out:
# (532408, 2)

# %%
# rename 'name' column
truth_df.rename(columns={'name':'ground_truth'},inplace=True)

# %%
truth_df.drop_duplicates(subset=['seq_id'], inplace=True)

# %%
truth_df.shape
# Out:
# (500000, 2)

# %% [markdown]
# ### Merge outputs

# %%
combined_df = pd.merge(truth_df,kraken_df, on='seq_id', how='left')

# %%
combined_df.columns
# Out:
# Index(['seq_id', 'name_minimap', 'status', 'taxonomy_id', 'taxon', 'name',
#        'name_kraken', 'genus'],
#       dtype='object')

# %%
combined_df.shape
# Out:
# (500000, 8)

# %%
combined_df.drop(['status', 'taxonomy_id'], axis=1,inplace=True)

# %%
combined_df.head(50)
# Out:
#    seq_id                             name_minimap taxon  \
# 0    seq1  Lactobacillus_fermentum_complete_genome     S
# 1    seq2         Staphylococcus_aureus_chromosome     G
# 2    seq3         Staphylococcus_aureus_chromosome     S
# 3    seq4  Lactobacillus_fermentum_complete_genome     S
# 4    seq5      Salmonella_enterica_complete_genome    S1
# 5    seq6            BS.pilon.polished.v3.ST170922     S
# 6    seq7         Staphylococcus_aureus_chromosome     S
# 7    seq8   Listeria_monocytogenes_complete_genome     G
# 8    seq9    Enterococcus_faecalis_complete_genome     S
# 9   seq10      Salmonella_enterica_complete_genome    S1
# 10  seq11                 Saccharomyces cerevisiae    S1
# 11  seq12      Salmonella_enterica_complete_genome     S
# 12  seq13                 Saccharomyces cerevisiae    S1
# 13  seq14    Enterococcus_faecalis_complete_genome     S
# 14  seq15    Enterococcus_faecalis_complete_genome     S
# 15  seq16    Enterococcus_faecalis_complete_genome     S
# 16  seq17    Enterococcus_faecalis_complete_genome     S
# 17  seq18            BS.pilon.polished.v3.ST170922     S
# 18  seq19            BS.pilon.polished.v3.ST170922     S
# 19  seq20            BS.pilon.polished.v3.ST170922     S
# 20  seq21   Listeria_monocytogenes_complete_genome     G
# 21  seq22      Salmonella_enterica_complete_genome     S
# 22  seq23   Listeria_monocytogenes_complete_genome     S
# 23  seq24                 Saccharomyces cerevisiae    S1
# 24  seq25    Enterococcus_faecalis_complete_genome     S
# 25  seq26   Pseudomonas_aeruginosa_complete_genome     S
# 26  seq27      Salmonella_enterica_complete_genome     S
# 27  seq28    Enterococcus_faecalis_complete_genome     S
# 28  seq29      Salmonella_enterica_complete_genome    S3
# 29  seq30         Staphylococcus_aureus_chromosome     S
# 30  seq31   Pseudomonas_aeruginosa_complete_genome     G
# 31  seq32                  Cryptococcus neoformans    S1
# 32  seq33   Pseudomonas_aeruginosa_complete_genome     S
# 33  seq34    Enterococcus_faecalis_complete_genome     S
# 34  seq35   Pseudomonas_aeruginosa_complete_genome     S
# 35  seq36  Lactobacillus_fermentum_complete_genome     S
# 36  seq37                  Cryptococcus neoformans    S2
# 37  seq38    Enterococcus_faecalis_complete_genome     S
# 38  seq39      Salmonella_enterica_complete_genome     S
# 39  seq40   Listeria_monocytogenes_complete_genome     G
# 40  seq41            BS.pilon.polished.v3.ST170922     S
# 41  seq42         Staphylococcus_aureus_chromosome    S1
# 42  seq43   Listeria_monocytogenes_complete_genome     S
# 43  seq44    Enterococcus_faecalis_complete_genome     S
# 44  seq45            BS.pilon.polished.v3.ST170922     S
# 45  seq46      Salmonella_enterica_complete_genome    S2
# 46  seq47                  Cryptococcus neoformans    S2
# 47  seq48         Staphylococcus_aureus_chromosome     S
# 48  seq49    Enterococcus_faecalis_complete_genome     S
# 49  seq50              Escherichia_coli_chromosome     S
#
#                                                  name  \
# 0                       Limosilactobacillus fermentum
# 1                                      Staphylococcus
# 2                               Staphylococcus aureus
# 3                       Limosilactobacillus fermentum
# 4                 Salmonella enterica subsp. enterica
# 5                                 Bacillus spizizenii
# 6                               Staphylococcus aureus
# 7                                            Listeria
# 8                               Enterococcus faecalis
# 9                 Salmonella enterica subsp. enterica
# 10                     Saccharomyces cerevisiae S288C
# 11                                Salmonella enterica
# 12                     Saccharomyces cerevisiae S288C
# 13                              Enterococcus faecalis
# 14                              Enterococcus faecalis
# 15                              Enterococcus faecalis
# 16                              Enterococcus faecalis
# 17                                Bacillus spizizenii
# 18                                Bacillus spizizenii
# 19                                Bacillus spizizenii
# 20                                           Listeria
# 21                                Salmonella enterica
# 22                                Listeria welshimeri
# 23                     Saccharomyces cerevisiae S288C
# 24                              Enterococcus faecalis
# 25                             Pseudomonas aeruginosa
# 26                                Salmonella enterica
# 27                              Enterococcus faecalis
# 28  Salmonella enterica subsp. enterica serovar Sl...
# 29                              Staphylococcus aureus
# 30                                        Pseudomonas
# 31            Cryptococcus neoformans var. neoformans
# 32                             Pseudomonas aeruginosa
# 33                              Enterococcus faecalis
# 34                             Pseudomonas aeruginosa
# 35                      Limosilactobacillus fermentum
# 36      Cryptococcus neoformans var. neoformans JEC21
# 37                              Enterococcus faecalis
# 38                                Salmonella enterica
# 39                                           Listeria
# 40                                Bacillus spizizenii
# 41      Staphylococcus aureus subsp. aureus Tager 104
# 42                                   Listeria innocua
# 43                              Enterococcus faecalis
# 44                                Bacillus spizizenii
# 45  Salmonella enterica subsp. enterica serovar Ad...
# 46      Cryptococcus neoformans var. neoformans JEC21
# 47                              Staphylococcus aureus
# 48                              Enterococcus faecalis
# 49                                   Escherichia coli
#
#                       name_kraken                genus
# 0   Limosilactobacillus fermentum  Limosilactobacillus
# 1                         unknown       Staphylococcus
# 2           Staphylococcus aureus       Staphylococcus
# 3   Limosilactobacillus fermentum  Limosilactobacillus
# 4             Salmonella enterica           Salmonella
# 5             Bacillus spizizenii             Bacillus
# 6           Staphylococcus aureus       Staphylococcus
# 7                         unknown             Listeria
# 8           Enterococcus faecalis         Enterococcus
# 9             Salmonella enterica           Salmonella
# 10       Saccharomyces cerevisiae        Saccharomyces
# 11            Salmonella enterica           Salmonella
# 12       Saccharomyces cerevisiae        Saccharomyces
# 13          Enterococcus faecalis         Enterococcus
# 14          Enterococcus faecalis         Enterococcus
# 15          Enterococcus faecalis         Enterococcus
# 16          Enterococcus faecalis         Enterococcus
# 17            Bacillus spizizenii             Bacillus
# 18            Bacillus spizizenii             Bacillus
# 19            Bacillus spizizenii             Bacillus
# 20                        unknown             Listeria
# 21            Salmonella enterica           Salmonella
# 22            Listeria welshimeri             Listeria
# 23       Saccharomyces cerevisiae        Saccharomyces
# 24          Enterococcus faecalis         Enterococcus
# 25         Pseudomonas aeruginosa          Pseudomonas
# 26            Salmonella enterica           Salmonella
# 27          Enterococcus faecalis         Enterococcus
# 28            Salmonella enterica           Salmonella
# 29          Staphylococcus aureus       Staphylococcus
# 30                        unknown          Pseudomonas
# 31        Cryptococcus neoformans         Cryptococcus
# 32         Pseudomonas aeruginosa          Pseudomonas
# 33          Enterococcus faecalis         Enterococcus
# 34         Pseudomonas aeruginosa          Pseudomonas
# 35  Limosilactobacillus fermentum  Limosilactobacillus
# 36        Cryptococcus neoformans         Cryptococcus
# 37          Enterococcus faecalis         Enterococcus
# 38            Salmonella enterica           Salmonella
# 39                        unknown             Listeria
# 40            Bacillus spizizenii             Bacillus
# 41          Staphylococcus aureus       Staphylococcus
# 42               Listeria innocua             Listeria
# 43          Enterococcus faecalis         Enterococcus
# 44            Bacillus spizizenii             Bacillus
# 45            Salmonella enterica           Salmonella
# 46        Cryptococcus neoformans         Cryptococcus
# 47          Staphylococcus aureus       Staphylococcus
# 48          Enterococcus faecalis         Enterococcus
# 49               Escherichia coli          Escherichia

# %%
combined_df['name_kraken'] = combined_df['name_kraken'].apply(lambda x:x.strip())
combined_df['ground_truth'] = combined_df['ground_truth'].apply(lambda x:x.strip())

# %%
combined_df[['ground_truth']].value_counts()
# Out:
# name_minimap
# Listeria_monocytogenes_complete_genome     50039
# Cryptococcus neoformans                    50009
# BS.pilon.polished.v3.ST170922              50000
# Lactobacillus_fermentum_complete_genome    50000
# Pseudomonas_aeruginosa_complete_genome     50000
# Salmonella_enterica_complete_genome        50000
# Enterococcus_faecalis_complete_genome      49961
# Staphylococcus_aureus_chromosome           49879
# Saccharomyces cerevisiae                   49217
# Escherichia_coli_chromosome                48907
# Escherichia_coli_plasmid                    1093
# None                                         774
# Staphylococcus_aureus_plasmid1               121
# dtype: int64

# %%
combined_df[['name_kraken']].value_counts(sort=True).head(40)
# Out:
# name_kraken
# unknown                          54525
# Cryptococcus neoformans          49987
# Limosilactobacillus fermentum    49949
# Enterococcus faecalis            48970
# Bacillus spizizenii              48701
# Salmonella enterica              45495
# Saccharomyces cerevisiae         44524
# Staphylococcus aureus            44487
# Pseudomonas aeruginosa           44143
# Escherichia coli                 32584
# Listeria monocytogenes           23428
# Listeria innocua                  2112
# Actinomyces oris                  1397
# Bacillus wiedmannii                977
# Listeria welshimeri                560
# Shigella flexneri                  463
# Listeria seeligeri                 420
# Escherichia albertii               416
# Listeria ivanovii                  399
# Escherichia fergusonii             295
# Shigella dysenteriae               278
# Escherichia marmotae               212
# Bacillus subtilis                  207
# Staphylococcus argenteus           191
# Shigella boydii                    191
# Bacillus velezensis                186
# Salmonella bongori                 176
# Escherichia sp. E4742              164
# Puccinia striiformis               164
# Homo sapiens                       151
# Klebsiella pneumoniae              150
# Staphylococcus schweitzeri         113
# Shigella sonnei                    100
# [Candida] auris                     76
# Toxoplasma gondii                   72
# Brettanomyces bruxellensis          59
# Saccharomyces paradoxus             59
# Staphylococcus simiae               54
# Fusarium keratoplasticum            53
# Enterococcus faecium                51
# dtype: int64

# %% [markdown]
# ## Mapping subspecies

# %% [markdown]
# Some label names can contain subspecies names. They have to be renamed with species name since the classification is done in species level.\
# Place those species names in following list.

# %%
genomes = [
    'Saccharomyces_cerevisiae',
    'Cryptococcus_neoformans',
    'Escherichia_coli',
    'Staphylococcus_aureus'
]

all_species = list(set(combined_df['ground_truth']))

# %%
mapping = {}

for genome in genomes:
  for species in all_species:
    if genome in species:
      mapping[species] = genome

# %%
mapping
# Out:
# {'CP006167.2_Saccharomyces_cerevisiae_YJM1307_chromosome_XVI_sequence': 'Saccharomyces_cerevisiae',
#  'CP005636.2_Saccharomyces_cerevisiae_YJM1307_chromosome_XV_sequence': 'Saccharomyces_cerevisiae',
#  'CP005031.2_Saccharomyces_cerevisiae_YJM1307_chromosome_IX_sequence': 'Saccharomyces_cerevisiae',
#  'CP006075.2_Saccharomyces_cerevisiae_YJM1307_chromosome_VIII_sequence': 'Saccharomyces_cerevisiae',
#  'CP006391.1_Saccharomyces_cerevisiae_YJM1307_chromosome_XII_sequence': 'Saccharomyces_cerevisiae',
#  'CP004640.2_Saccharomyces_cerevisiae_YJM1307_chromosome_II_genomic_sequence': 'Saccharomyces_cerevisiae',
#  'CP006287.1_Saccharomyces_cerevisiae_YJM1307_chromosome_III': 'Saccharomyces_cerevisiae',
#  'CP005144.1_Saccharomyces_cerevisiae_YJM1307_chromosome_X_sequence': 'Saccharomyces_cerevisiae',
#  'CP005339.2_Saccharomyces_cerevisiae_YJM1307_chromosome_XI_sequence': 'Saccharomyces_cerevisiae',
#  'CP004458.2_Saccharomyces_cerevisiae_YJM1307_chromosome_I_genomic_sequence': 'Saccharomyces_cerevisiae',
#  'CP005242.2_Saccharomyces_cerevisiae_YJM1307_chromosome_VII_genomic_sequence': 'Saccharomyces_cerevisiae',
#  'CP005542.2_Saccharomyces_cerevisiae_YJM1307_chromosome_XIV_sequence': 'Saccharomyces_cerevisiae',
#  'CP005440.1_Saccharomyces_cerevisiae_YJM1307_chromosome_XIII_sequence': 'Saccharomyces_cerevisiae',
#  'CP004708.2_Saccharomyces_cerevisiae_YJM1307_chromosome_IV_sequence': 'Saccharomyces_cerevisiae',
#  'CP004803.2_Saccharomyces_cerevisiae_YJM1307_chromosome_V_sequence': 'Saccharomyces_cerevisiae',
#  'CP004938.2_Saccharomyces_cerevisiae_YJM1307_chromosome_VI_sequence': 'Saccharomyces_cerevisiae',
#  'NC_006691.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_6_sequence': 'Cryptococcus_neoformans',
#  'NC_006681.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_12_sequence': 'Cryptococcus_neoformans',
#  'NC_006694.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_9_sequence': 'Cryptococcus_neoformans',
#  'NC_006670.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_1,_complete_sequence': 'Cryptococcus_neoformans',
#  'NC_006686.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_4_sequence': 'Cryptococcus_neoformans',
#  'NC_006682.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_13_sequence': 'Cryptococcus_neoformans',
#  'NC_006692.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_7_sequence': 'Cryptococcus_neoformans',
#  'NC_006679.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_10_sequence': 'Cryptococcus_neoformans',
#  'NC_006684.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_2_sequence': 'Cryptococcus_neoformans',
#  'NC_006680.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_11_sequence': 'Cryptococcus_neoformans',
#  'NC_006687.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_5_sequence': 'Cryptococcus_neoformans',
#  'NC_006685.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_3_sequence': 'Cryptococcus_neoformans',
#  'NC_006693.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_8_sequence': 'Cryptococcus_neoformans',
#  'NC_006683.1_Cryptococcus_neoformans_var._neoformans_JEC21_chromosome_14_sequence': 'Cryptococcus_neoformans',
#  'Escherichia_coli_chromosome': 'Escherichia_coli',
#  'Escherichia_coli_plasmid': 'Escherichia_coli',
#  'Staphylococcus_aureus_chromosome': 'Staphylococcus_aureus',
#  'Staphylococcus_aureus_plasmid1': 'Staphylococcus_aureus'}

# %%
combined_df['ground_truth'] = combined_df['ground_truth'].replace(mapping)

# %%
combined_df[['ground_truth']].value_counts()
# Out:
# ground_truth
# BS.pilon.polished.v3.ST170922                      50000
# Cryptococcus_neoformans                            50000
# Enterococcus_faecalis_complete_genome_2.845Mb      50000
# Escherichia_coli                                   50000
# Lactobacillus_fermentum_complete_genome_1.905Mb    50000
# Listeria_monocytogenes_complete_genome_2.992Mb     50000
# Pseudomonas_aeruginosa_complete_genome_6,792Mb     50000
# Saccharomyces_cerevisiae                           50000
# Salmonella_enterica_complete_genome_4.760Mb        50000
# Staphylococcus_aureus                              50000
# dtype: int64

# %%
combined_df[['name_kraken']].value_counts().head(20)
# Out:
# name_kraken
# unknown                          54525
# Cryptococcus neoformans          49987
# Limosilactobacillus fermentum    49949
# Enterococcus faecalis            48970
# Bacillus spizizenii              48701
# Salmonella enterica              45495
# Saccharomyces cerevisiae         44524
# Staphylococcus aureus            44487
# Pseudomonas aeruginosa           44143
# Escherichia coli                 32584
# Listeria monocytogenes           23428
# Listeria innocua                  2112
# Actinomyces oris                  1397
# Bacillus wiedmannii                977
# Listeria welshimeri                560
# Shigella flexneri                  463
# Listeria seeligeri                 420
# Escherichia albertii               416
# Listeria ivanovii                  399
# Escherichia fergusonii             295
# dtype: int64

# %% [markdown]
# # Mapping names

# %% [markdown]
# This is done when Kraken2 names and ground truth label names does not match.\
# For example, **Lactobacillus_fermentum_complete_genome** and **Limosilactobacillus fermentum** is the same species.

# %%
kraken_map = {
    'Lactobacillus_fermentum_complete_genome_1.905Mb' : 'Limosilactobacillus fermentum',
    'Enterococcus_faecalis_complete_genome_2.845Mb' : 'Enterococcus faecalis',
    'Enterococcus_faecalis_complete_genome_2.845Mb' : 'Enterococcus faecalis',
    'Escherichia_coli': 'Escherichia coli',
    'Listeria_monocytogenes_complete_genome_2.992Mb' : 'Listeria monocytogenes',
    'Pseudomonas_aeruginosa_complete_genome_6,792Mb' : 'Pseudomonas aeruginosa',
    'Salmonella_enterica_complete_genome_4.760Mb' : 'Salmonella enterica',
    'Staphylococcus_aureus' : 'Staphylococcus aureus',
    'BS.pilon.polished.v3.ST170922' : 'Bacillus subtilis',
    'Saccharomyces_cerevisiae' : 'Saccharomyces cerevisiae',
    'Cryptococcus_neoformans' : 'Cryptococcus neoformans'
}

# %%
combined_df['ground_truth'] = combined_df['ground_truth'].replace(kraken_map)

# %%
mapping_df = combined_df[['ground_truth','name_kraken']].value_counts().to_frame()
mapping_df
# Out:
#                                                                  0
# ground_truth                  name_kraken
# Cryptococcus neoformans       Cryptococcus neoformans        49986
# Limosilactobacillus fermentum Limosilactobacillus fermentum  49949
# Enterococcus faecalis         Enterococcus faecalis          48945
# Bacillus subtilis             Bacillus spizizenii            48701
# Salmonella enterica           Salmonella enterica            45315
# ...                                                            ...
# Pseudomonas aeruginosa        Pseudomonas koreensis              1
#                               Pseudomonas juntendi               1
#                               Pseudomonas iranensis              1
#                               Pseudomonas graminis               1
#                               Pseudomonas serboccidentalis       1
#
# [854 rows x 1 columns]

# %%
combined_df[combined_df['name_kraken'] == 'unknown']
# Out:
#            seq_id                            name_minimap taxon  \
# 1            seq2        Staphylococcus_aureus_chromosome     G
# 7            seq8  Listeria_monocytogenes_complete_genome     G
# 20          seq21  Listeria_monocytogenes_complete_genome     G
# 30          seq31  Pseudomonas_aeruginosa_complete_genome     G
# 39          seq40  Listeria_monocytogenes_complete_genome     G
# ...           ...                                     ...   ...
# 499955  seq499956  Listeria_monocytogenes_complete_genome     G
# 499961  seq499962             Escherichia_coli_chromosome     F
# 499982  seq499983  Listeria_monocytogenes_complete_genome     G
# 499985  seq499986  Pseudomonas_aeruginosa_complete_genome     P
# 499993  seq499994                Saccharomyces cerevisiae    G1
#
#                          name name_kraken           genus  \
# 1              Staphylococcus     unknown  Staphylococcus
# 7                    Listeria     unknown        Listeria
# 20                   Listeria     unknown        Listeria
# 30                Pseudomonas     unknown     Pseudomonas
# 39                   Listeria     unknown        Listeria
# ...                       ...         ...             ...
# 499955               Listeria     unknown        Listeria
# 499961     Enterobacteriaceae     unknown         unknown
# 499982               Listeria     unknown        Listeria
# 499985         Pseudomonadota     unknown         unknown
# 499993  Bacillus cereus group     unknown        Bacillus
#
#                     ground_truth
# 1          Staphylococcus aureus
# 7         Listeria monocytogenes
# 20        Listeria monocytogenes
# 30        Pseudomonas aeruginosa
# 39        Listeria monocytogenes
# ...                          ...
# 499955    Listeria monocytogenes
# 499961          Escherichia coli
# 499982    Listeria monocytogenes
# 499985    Pseudomonas aeruginosa
# 499993  Saccharomyces cerevisiae
#
# [54525 rows x 7 columns]

# %%
combined_df.shape
# Out:
# (500000, 7)

# %%
combined_df.to_csv(f'{kraken_path}/kraken_minimap.csv',index=None)
